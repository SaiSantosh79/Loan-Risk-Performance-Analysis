# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px

# %%
# !pip install openpyxl

# %%
fin=pd.read_excel("C:/Users/santo/Downloads/financial_loan.xlsx")

# %%
fin.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
fin.tail()
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE 2021-07-11
# 38572                        Swat Fame     C           RENT 2021-10-11
# 38573  Anaheim Regional Medical Center     D           RENT 2021-09-11
# 38574               Brooklyn Radiology     D           RENT 2021-10-11
# 38575                    Allen Edmonds     F           RENT 2021-07-11
#
#       last_credit_pull_date last_payment_date  ... sub_grade        term  \
# 38571            2021-05-16        2021-05-16  ...        C1   60 months
# ...

# %% [markdown]
# # Metadata of data

# %%
print(f'No.Of Rows:{fin.shape[0]}')
# Out:
# No.Of Rows:38576

# %%
print(f'No.Of Columns:{fin.shape[1]}')
# Out:
# No.Of Columns:24

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %% [markdown]
# # Datatypes

# %%
fin.dtypes
# Out:
# id                                int64
# address_state                    object
# application_type                 object
# emp_length                       object
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# member_id                         int64
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# ...

# %%
fin.describe()
# Out:
#                  id                     issue_date  \
# count  3.857600e+04                          38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007040
# min    5.473400e+04            2021-01-01 00:00:00
# 25%    5.135170e+05            2021-04-11 00:00:00
# 50%    6.627280e+05            2021-07-11 00:00:00
# 75%    8.365060e+05            2021-10-11 00:00:00
# max    1.077501e+06            2021-12-12 00:00:00
# std    2.113246e+05                            NaN
#
#                last_credit_pull_date              last_payment_date  \
# count                          38576                          38576
# mean   2021-06-08 13:36:34.193280512  2021-06-26 09:52:08.909166080
# min              2021-01-08 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-15 00:00:00            2021-03-16 00:00:00
# 50%              2021-05-16 00:00:00            2021-06-14 00:00:00
# 75%              2021-08-13 00:00:00            2021-09-15 00:00:00
# ...

# %% [markdown]
# # Total Applications

# %%
tot_app=fin['id'].count()
print(f'Total No OF Application:{tot_app}')
# Out:
# Total No OF Application:38576

# %% [markdown]
# # MTD Total Loan Applications

# %%
latest_issue_date=fin['issue_date'].max()
latest_year=latest_issue_date.year
latest_month=latest_issue_date.month

mtd_date=fin[(fin['issue_date'].dt.year==latest_year) & (fin['issue_date'].dt.month==latest_month)]

mtd_loan_applications=mtd_date['id'].count()

print(f"MTD Loan Applications (for {latest_issue_date.strftime('%B' '%Y')}) : {mtd_loan_applications}")
# Out:
# MTD Loan Applications (for December2021) : 4314

# %% [markdown]
# #  Total Funded Amount

# %%
tot_fund_amt=fin['loan_amount'].sum()
tot_fund_amt_m=tot_fund_amt/1000000
print("Total Funded Amount: ${:.2f}M".format(tot_fund_amt_m))
# Out:
# Total Funded Amount: $435.76M

# %% [markdown]
# # MTD Total Funded Amount

# %%
latest_issue_date=fin['issue_date'].max()
latest_year=latest_issue_date.year
latest_month=latest_issue_date.month

mtd_date=fin[(fin['issue_date'].dt.year==latest_year) & (fin['issue_date'].dt.month==latest_month)]

mtd_tot_funded_amt=mtd_date['loan_amount'].sum()
mtd_tot_funded_amt_m=mtd_tot_funded_amt/1000000

print("MTD Total Funded Amount ${:.2f}M".format(mtd_tot_funded_amt_m))
# Out:
# MTD Total Funded Amount $53.98M

# %% [markdown]
# # Total Amount Received

# %%
tot_amt=fin['total_payment'].sum()
tot_amt_m=tot_amt/1000000
print("Total Funded Amount: ${:.2f}M".format(tot_amt_m))
# Out:
# Total Funded Amount: $473.07M

# %% [markdown]
# # MTD Total Amount Received

# %%
latest_issue_date=fin['issue_date'].max()
latest_year=latest_issue_date.year
latest_month=latest_issue_date.month

mtd_date=fin[(fin['issue_date'].dt.year==latest_year) & (fin['issue_date'].dt.month==latest_month)]

mtd_tot_amt=mtd_date['total_payment'].sum()
mtd_tot_amt_m=mtd_tot_amt/1000000

print("MTD Total  Amount ${:.2f}M".format(mtd_tot_amt_m))
# Out:
# MTD Total  Amount $58.07M

# %% [markdown]
# # AVG Interest Rate

# %%
avg_int_rate=fin['int_rate'].mean()*100
print("avg int rate:{:.2f}%".format(avg_int_rate))
# Out:
# avg int rate:12.05%

# %% [markdown]
# # AVG Debt-to-income Ratio (DTI)

# %%
avg_dti=fin['dti'].mean()*100
print("avg dti:{:.2f}%".format(avg_dti))
# Out:
# avg dti:13.33%

# %% [markdown]
# # Good Loan Matrix

# %%
good_loans= fin[fin["loan_status"].isin(["Fully Paid", "Current"])]
total_loan_applications= fin["id"].count()
good_loan_applications= good_loans['id'].count()
good_loan_funded_amount= good_loans[ "loan_amount"].sum()
good_loan_received= good_loans ['total_payment'].sum()
good_loan_funded_amount_millions= good_loan_funded_amount / 1000000
good_loan_received_millions= good_loan_received / 1000000
good_loan_percentage =(good_loan_applications/total_loan_applications) *100
print("Good Loan Applications:", good_loan_applications)
print("Good Loan Funded Amount (in Millions): ${:.2f} M".format(good_loan_funded_amount_millions))
print("Good Loan Total Received (in Millions): ${:.2f} M".format(good_loan_received_millions))
print("Percentage of Good Loan Applications: {:.2f}%".format(good_loan_percentage))
# Out:
# Good Loan Applications: 33243
# Good Loan Funded Amount (in Millions): $370.22 M
# Good Loan Total Received (in Millions): $435.79 M
# Percentage of Good Loan Applications: 86.18%

# %% [markdown]
# # Bad Loan Matrix

# %%
Bad_loans= fin[fin["loan_status"].isin(["Charged Off"])]
total_loan_applications= fin["id"].count()
Bad_loan_applications= Bad_loans['id'].count()
Bad_loan_funded_amount= Bad_loans[ "loan_amount"].sum()
Bad_loan_received= Bad_loans ['total_payment'].sum()
Bad_loan_funded_amount_millions= Bad_loan_funded_amount / 1000000
Bad_loan_received_millions= Bad_loan_received / 1000000
Bad_loan_percentage =(Bad_loan_applications/total_loan_applications) *100
print("Bad Loan Applications:", Bad_loan_applications)
print("Bad Loan Funded Amount (in Millions): ${:.2f} M".format(Bad_loan_funded_amount_millions))
print("Bad Loan Total Received (in Millions): ${:.2f} M".format(Bad_loan_received_millions))
print("Percentage of Bad Loan Applications: {:.2f}%".format(Bad_loan_percentage))
# Out:
# Bad Loan Applications: 5333
# Bad Loan Funded Amount (in Millions): $65.53 M
# Bad Loan Total Received (in Millions): $37.28 M
# Percentage of Bad Loan Applications: 13.82%

# %% [markdown]
# # Monthly Trends By isuue Date for total Funded amount

# %%
import matplotlib.pyplot as plt

monthly_funded = (
    fin.sort_values("issue_date")
    .assign(month_name=lambda x: x["issue_date"].dt.strftime("%b %Y"))
    .groupby("month_name", sort=False)["loan_amount"]
    .sum()
    .div(1_000_000)
    .reset_index(name="loan_amount_millions")
)

plt.figure(figsize=(10, 5))

# Area plot
plt.fill_between(
    monthly_funded['month_name'],
    monthly_funded['loan_amount_millions'],
    color='skyblue',
    alpha=0.5
)

# Line plot
plt.plot(
    monthly_funded['month_name'],
    monthly_funded['loan_amount_millions'],
    color="blue",
    linewidth=2
)

# Labels on points
for i, row in monthly_funded.iterrows():
    plt.text(
        i,
        row['loan_amount_millions'] + 0.1,
        f"{row['loan_amount_millions']:.2f}",
        ha='center',
        va='bottom',
        fontsize=9
    )

# Titles and labels
plt.title('Total Funded Amount by Month', fontsize=14)
plt.xlabel("Month")
plt.ylabel("Funded Amount ($Millions)")

plt.xticks(
    ticks=range(len(monthly_funded)),
    labels=monthly_funded['month_name'],
    rotation=45
)

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly Trends By issue Date for Total Amount Received

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure date column is datetime
fin['issue_date'] = pd.to_datetime(fin['issue_date'])

monthly_received = (
    fin.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False)['total_payment']
    .sum()
    .div(1_000_000)
    .reset_index(name='received_amount_millions')
)

plt.figure(figsize=(10, 5))

# Area plot
plt.fill_between(
    monthly_received['month_name'],
    monthly_received['received_amount_millions'],
    color='lightgreen',
    alpha=0.5
)

# Line plot
plt.plot(
    monthly_received['month_name'],
    monthly_received['received_amount_millions'],
    color='green',
    linewidth=2
)

# Labels on points
for i, row in monthly_received.iterrows():
    plt.text(
        i,
        row['received_amount_millions'] + 0.1,
        f"{row['received_amount_millions']:.2f}",
        ha='center',
        va='bottom',
        fontsize=9
    )

# Titles and labels
plt.title('Total Received Amount by Month', fontsize=14)
plt.xlabel("Month")
plt.ylabel('Received Amount (Millions)')

plt.xticks(
    ticks=range(len(monthly_received)),
    labels=monthly_received['month_name'],
    rotation=45
)

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly Trends by issue date for total loan applications

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure datetime format
fin['issue_date'] = pd.to_datetime(fin['issue_date'])

monthly_applications = (
    fin.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False)['id']
    .count()
    .reset_index(name='loan_applications_count')
)

plt.figure(figsize=(10, 5))

# Area plot
plt.fill_between(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color="orange",
    alpha=0.5
)

# Line plot
plt.plot(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color="brown",
    marker='.',
    linewidth=2
)

# Labels on points
for i, row in monthly_applications.iterrows():
    plt.text(
        i,
        row['loan_applications_count'] + 5,
        f"{row['loan_applications_count']}",
        ha='center',
        va='bottom',
        fontsize=9
    )

# Titles & labels
plt.title("Total Loan Applications by Month", fontsize=14)
plt.xlabel('Month')
plt.ylabel("Number of Applications")

plt.xticks(
    ticks=range(len(monthly_applications)),
    labels=monthly_applications['month_name'],
    rotation=45
)

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Regional Analysis by state for total funded amount

# %%
# Group by state
state_funding = (
    fin.groupby('address_state')['loan_amount']
    .sum()
    .sort_values(ascending=True)
)

# Convert to thousands
state_funding_thousands = state_funding / 1000

plt.figure(figsize=(10, 8))

# Horizontal bar chart
bars = plt.barh(
    state_funding_thousands.index,
    state_funding_thousands.values,
    color='black'
)

# Add labels on bars
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 10,
        bar.get_y() + bar.get_height() / 2,
        f"{width:,.0f}",
        va='center',
        fontsize=9
    )

# Titles and labels
plt.title('Total Funded Amount by State (in Thousands)')
plt.xlabel("Funded Amount ('000)")
plt.ylabel("State")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Regional Analysis by state for total recieved amount

# %%
# Group by state
state_payment = (
    fin.groupby('address_state')['total_payment']
    .sum()
    .sort_values(ascending=True)
)

# Convert to thousands
state_payment_thousands = state_payment / 1000

plt.figure(figsize=(10, 8))

# Horizontal bar chart
bars = plt.barh(
    state_payment_thousands.index,
    state_payment_thousands.values,
    color='pink'
)

# Add labels on bars
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 10,
        bar.get_y() + bar.get_height() / 2,
        f"{width:,.0f}",
        va='center',
        fontsize=9
    )

# Titles and labels
plt.title('Total payment Amount by State (in Thousands)')
plt.xlabel("Toatl Payemnt Amount ('000)")
plt.ylabel("State")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Loan Term Analysis by Total Funded Amount

# %%
import matplotlib.pyplot as plt

# Group by term
term_funding_millions = (
    fin.groupby('term')['loan_amount']
    .sum()
    .div(1_000_000)
)

plt.figure(figsize=(5, 5))

# Pie chart
plt.pie(
    term_funding_millions,
    labels=term_funding_millions.index,
    autopct=lambda p: f"{p:.1f}%\n${p * sum(term_funding_millions) / 100:.1f}M",
    startangle=90,
    wedgeprops={'width': 0.4},
    colors = ['#D32F2F', '#424242']
)

# Create donut hole
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))

plt.title("Total Funded Amount by Term (in Millions)")
plt.show()

# %% [markdown]
# # Loan Term Analysis by Total Recieved Amount

# %%
import matplotlib.pyplot as plt

# Group by term
term_received_millions = (
    fin.groupby('term')['total_payment']
    .sum()
    .div(1_000_000)
)

plt.figure(figsize=(5, 5))

# Pie chart
plt.pie(
    term_received_millions,
    labels=term_received_millions.index,
    autopct=lambda p: f"{p:.1f}%\n${p * sum(term_received_millions) / 100:.1f}M",
    startangle=90,
    wedgeprops={'width': 0.4}
)

# Create donut hole
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))

plt.title("Total Received Amount by Term (in Millions)")
plt.show()

# %% [markdown]
# # Loan Term Analysis by Total Application

# %%
import matplotlib.pyplot as plt

# Group by term
tot_app = (
    fin.groupby('term')['id']
    .count()
)

# Total applications
total = tot_app.sum()

plt.figure(figsize=(5, 5))

plt.pie(
    tot_app,
    labels=tot_app.index,
    autopct=lambda p: f"{p:.1f}%\n{int(p * total / 100)}",
    startangle=90,
    wedgeprops={'width': 0.4, 'edgecolor': 'white'},
    colors=['#2A9D8F', '#E76F51']  # change here
)

# Donut hole
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))

plt.title("Total Applications by Term")
plt.show()

# %% [markdown]
# # Employee Length By Total funded Amount

# %%
import matplotlib.pyplot as plt

# Group by employment length
emp_funding = (
    fin.groupby('emp_length')['loan_amount']
    .sum()
    .sort_values()
)

# Convert to thousands
emp_funding_thousands = emp_funding / 1000

plt.figure(figsize=(10, 6))

# Horizontal bar chart
bars = plt.barh(
    emp_funding_thousands.index,
    emp_funding_thousands.values,
    color="purple"
)

# Add labels
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 5,
        bar.get_y() + bar.get_height() / 2,
        f"{width:,.0f}K",
        va='center',
        fontsize=9
    )

# Labels & title
plt.xlabel("Funded Amount (Thousands)")
plt.title("Total Funded Amount by Employment Length")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Loan Purpose by total funded amount

# %%
import matplotlib.pyplot as plt

# Group by purpose
purpose_funding_millions = (
    fin.groupby('purpose')['loan_amount']
    .sum()
    .sort_values()
    .div(1_000_000)
)

plt.figure(figsize=(10, 6))

# Horizontal bar chart
bars = plt.barh(
    purpose_funding_millions.index,
    purpose_funding_millions.values,
    color='skyblue'
)

# Add labels
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 0.1,
        bar.get_y() + bar.get_height() / 2,
        f"{width:.2f}M",
        va='center',
        fontsize=9
    )

# Titles & labels
plt.title('Total Funded Amount by Loan Purpose (Millions)', fontsize=14)
plt.xlabel("Funded Amount (Millions)")
plt.ylabel("Loan Purpose")

plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Home ownership by total funded amount

# %%
import plotly.express as px

# Group by home ownership
home_funding = (
    fin.groupby('home_ownership')['loan_amount']
    .sum()
    .reset_index()
)

# Convert to millions
home_funding['loan_amount_millions'] = home_funding['loan_amount'] / 1_000_000

# Treemap
fig = px.treemap(
    home_funding,
    path=['home_ownership'],
    values='loan_amount_millions',
    color='loan_amount_millions',
    color_continuous_scale='Blues',
    title='Total Funded Amount by Home Ownership (Millions)'
)

fig.show()
